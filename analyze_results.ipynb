# %%
import pandas as pd
from pathlib import Path

# %%
results_path = Path("./data/results")
label_df = pd.read_csv(results_path / "test_papers.csv")
chatgpt_df = pd.read_csv(results_path / "chatgpt_results.csv")
claude_df = pd.read_csv(results_path / "claude_results.csv")
llama_df = pd.read_csv(results_path / "llama_results.csv")

# %%
# Rename columns to include model prefixes
chatgpt_df = chatgpt_df.rename(columns={
    "Decision": "chatgpt_decision",
    "Reason": "chatgpt_reason",
    "Note": "chatgpt_note"
})

claude_df = claude_df.rename(columns={
    "Decision": "claude_decision",
    "Reason": "claude_reason",
    "Note": "claude_note"
})

llama_df = llama_df.rename(columns={
    "Decision": "llama_decision",
    "Reason": "llama_reason",
    "Note": "llama_note"
})

# %%
# Merge the dataframes on 'Title'
merged_df = label_df.merge(chatgpt_df, on="Title", how="left")
merged_df = merged_df.merge(claude_df, on="Title", how="left")
merged_df = merged_df.merge(llama_df, on="Title", how="left")

# %%
merged_df
# Out:
#                                                 Title  Decision  \
# 0   PCovNet+: A CNN-VAE anomaly detection framewor...   Include
# 1   Classification of Sleep-Wake State in Ballisto...   Include
# 2   SeizFt: Interpretable Machine Learning for Sei...   Include
# 3   Development of artificial intelligence edge co...   Include
# 4   Analysis of Data from Wearable Sensors for Sle...   Include
# 5   Are Machine Learning Models on Wrist Accelerom...   Include
# 6   Telemonitoring of Daily Activity Using Acceler...   Include
# 7   Real-time detection of freezing of gait in Par...   Include
# 8   An unbiased, efficient sleep-wake detection al...   Include
# 9   A new smart wristband equipped with an artific...   Include
# 10  An Interpretable Deep Learning Optimized Weara...   Include
# 11  Robust Feature Selection for BP Estimation in ...   Include
# 12  Deep learning with wearable based heart rate v...   Include
# 13  Ecological Momentary Assessments and Passive S...   Include
# 14  Novel non-invasive in-house fabricated wearabl...   Include
# 15  AccNet24: A deep learning framework for classi...   Include
# 16  A Teenager Physical Fitness Evaluation Model B...   Include
# 17  A machine learning approach to determine resil...   Include
# 18  Quantitative detection of sleep apnea in adult...   Include
# 19  Heart Rate and CGM Feature Representation Diab...   Include
# 20  Mechanocardiography in the Detection of Acute ...  Excluded
# 21  Detection and Characterization of Physical Act...  Excluded
# 22  Mental stress recognition on the fly using neu...  Excluded
# 23  Hybrid Amplitude Ordinal Partition Networks fo...  Excluded
# 24  Ambulatory Smartwatch ECG Monitoring among Pat...  Excluded
# 25  Fusion Learning on Multiple-Tag RFID Measureme...  Excluded
# 26  A CNN Model for Cardiac Arrhythmias Classifica...  Excluded
# 27  Combating False Data Injection Attacks on Huma...  Excluded
# 28  Development of an artificial intelligence syst...  Excluded
# 29  An Optimized Hardware Inference of SABiNN: Shi...  Excluded
# 30  A Comparison among Different Strategies to Det...  Excluded
# 31  Using Wearable Passive Sensing to Predict Bing...  Excluded
# 32  Artificial Intelligence-Based Atrial Fibrillat...  Excluded
# 33  Smartwatch Electrocardiograms for Automated an...  Excluded
# 34  Study Protocol for the Artificial Intelligence...  Excluded
# 35  Discrimination of simultaneous psychological a...  Excluded
# 36  Observational study protocol for an arrhythmia...  Excluded
# 37  Estimation of Gait Parameters in Huntington’s ...  Excluded
# 38  A Neural Network Estimation of Ankle Torques F...  Excluded
# 39  Exploratory Data Analysis of Human Activity Re...  Excluded
#
#                        Exclude Reason  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# 5                                 NaN
# 6                                 NaN
# 7                                 NaN
# 8                                 NaN
# 9                                 NaN
# 10                                NaN
# 11                                NaN
# 12                                NaN
# 13                                NaN
# 14                                NaN
# 15                                NaN
# 16                                NaN
# 17                                NaN
# 18                                NaN
# 19                                NaN
# 20              Sample size too small
# 21              Sample size too small
# 22              Sample size too small
# 23               Not wearable devices
# 24                  Wrong primary aim
# 25                 Not human subjects
# 26               Not wearable devices
# 27               Not wearable devices
# 28              Not original research
# 29               Not wearable devices
# 30                 Not human subjects
# 31              Not original research
# 32               Not wearable devices
# 33                  Wrong primary aim
# 34              Not original research
# 35              Sample size too small
# 36  Not data-driven fitting procedure
# 37              Sample size too small
# 38              Sample size too small
# 39              Sample size too small
#
#                                                 Notes chatgpt_decision  \
# 0                                                 NaN          Include
# 1                                                 NaN          Include
# 2                                                 NaN          Include
# 3                                                 NaN          Include
# 4                                                 NaN          Include
# 5                                                 NaN          Include
# 6                                                 NaN          Include
# 7                                                 NaN              NaN
# 8                                                 NaN              NaN
# 9                                                 NaN              NaN
# 10                                                NaN              NaN
# 11                                                NaN              NaN
# 12                                                NaN          Include
# 13                                                NaN          Include
# 14                                                NaN          Exclude
# 15                                                NaN          Include
# 16                                                NaN          Include
# 17                                                NaN          Include
# 18                                                NaN          Include
# 19                                                NaN              NaN
# 20  full text mentions "Thus, 41 patients with STE...          Exclude
# 21  looking at the full text "Data from 207 experi...          Include
# 22  full text mentions "The dataset used in this s...          Exclude
# 23  looking at the full text this study uses the f...          Include
# 24  Primary aim is to measure diagnostic efficacy ...          Include
# 25  “Data Collection - Our DYnamic Spectrum Enviro...          Include
# 26  "The ECG data used are from the Massachusetts\...              NaN
# 27  Primary aim is to evaluate false data injectio...          Include
# 28  Protocol describing methodology, not original ...          Exclude
# 29  looking at the full text the model was "traine...          Include
# 30  looking at the full text and figure 1a the dat...          Exclude
# 31                                protocol - excluded              NaN
# 32  not wearable: "In the experiment, (a) we extra...          Include
# 33                                                NaN          Include
# 34                                                NaN          Exclude
# 35  full text mentions "Thirty-four subjects parti...              NaN
# 36                                                NaN          Exclude
# 37  "Seventeen individuals with HD (5 female) part...              NaN
# 38  "Five subjects performed the experiment protoc...          Exclude
# 39  “The data we used came from the University of ...          Exclude
#
#            chatgpt_reason                                       chatgpt_note  \
# 0                     NaN                                                NaN
# 1                     NaN                                                NaN
# 2                     NaN                                                NaN
# 3                     NaN                                                NaN
# 4                     NaN                                                NaN
# 5                     NaN                                                NaN
# 6                     NaN                                                NaN
# 7                     NaN                                                NaN
# 8                     NaN                                                NaN
# 9                     NaN                                                NaN
# 10                    NaN                                                NaN
# 11                    NaN                                                NaN
# 12                    NaN                                                NaN
# 13                    NaN                                                NaN
# 14     Not human subjects  Clinical testing was conducted utilizing this ...
# 15                    NaN                                                NaN
# 16                    NaN                                                NaN
# 17                    NaN                                                NaN
# 18                    NaN                                                NaN
# 19                    NaN                                                NaN
# 20  Sample size too small  The study group consisted of 41 STEMI patients...
# 21                    NaN                                                NaN
# 22  Sample size too small  The dataset used in this study consists of EEG...
# 23                    NaN                                                NaN
# 24                    NaN                                                NaN
# 25                    NaN                                                NaN
# 26                    NaN                                                NaN
# 27                    NaN                                                NaN
# 28  Sample size too small  The study aims to recruit 30 patients with T1D...
# 29                    NaN                                                NaN
# 30     Not human subjects  The dataset was then randomized and divided in...
# 31                    NaN                                                NaN
# 32                    NaN                                                NaN
# 33                    NaN                                                NaN
# 34  Not original research  This is the protocol for a cross-sectional stu...
# 35                    NaN                                                NaN
# 36  Not original research  This paper describes a study protocol but does...
# 37                    NaN                                                NaN
# 38  Sample size too small  Five subjects performed the experiment protoco...
# 39   Not wearable devices  The HAR method based on the smart phone and ED...
#
#    claude_decision          claude_reason  \
# 0          Include                    NaN
# 1          Include                    NaN
# 2          Include                    NaN
# 3          Include                    NaN
# 4          Include                    NaN
# 5          Include                    NaN
# 6          Include                    NaN
# 7          Include                    NaN
# 8              NaN                    NaN
# 9              NaN                    NaN
# 10         Include                    NaN
# 11             NaN                    NaN
# 12         Include                    NaN
# 13         Include                    NaN
# 14         Include                    NaN
# 15         Include                    NaN
# 16         Include                    NaN
# 17         Include                    NaN
# 18         Include                    NaN
# 19         Include                    NaN
# 20         Include                    NaN
# 21         Include                    NaN
# 22         Exclude       Wrong input data
# 23         Include                    NaN
# 24         Include                    NaN
# 25         Exclude   Not wearable devices
# 26             NaN                    NaN
# 27         Include                    NaN
# 28         Include                    NaN
# 29         Include                    NaN
# 30         Include                    NaN
# 31             NaN                    NaN
# 32         Include                    NaN
# 33         Include                    NaN
# 34         Include                    NaN
# 35             NaN                    NaN
# 36         Exclude  Not original research
# 37             NaN                    NaN
# 38         Include                    NaN
# 39         Exclude       Wrong input data
#
#                                           claude_note llama_decision  \
# 0                                                 NaN        Exclude
# 1   Justification breakdown:\n1. Published in Engl...        Exclude
# 2   The paper meets all inclusion criteria:\n1. Pu...        Exclude
# 3                                                 NaN        Exclude
# 4                                                 NaN        Exclude
# 5                                                 NaN        Exclude
# 6                                                 NaN        Exclude
# 7                                                 NaN            NaN
# 8                                                 NaN            NaN
# 9                                                 NaN        Include
# 10                                                NaN            NaN
# 11                                                NaN        Exclude
# 12                                                NaN        Exclude
# 13                                                NaN        Include
# 14  Rationale for Inclusion:\n1. Published in Engl...        Include
# 15                                                NaN        Exclude
# 16                                                NaN        Exclude
# 17                                                NaN        Exclude
# 18                                                NaN        Exclude
# 19                                                NaN        Exclude
# 20                                                NaN        Exclude
# 21                                                NaN        Exclude
# 22                                                NaN            NaN
# 23                                                NaN        Exclude
# 24                                                NaN        Exclude
# 25                                                NaN        Exclude
# 26                                                NaN        Include
# 27                                                NaN        Include
# 28                                                NaN            NaN
# 29                                                NaN        Exclude
# 30                                                NaN        Exclude
# 31                                                NaN            NaN
# 32  My reasoning for inclusion:\n1. Published in E...        Exclude
# 33                                                NaN        Exclude
# 34                                                NaN            NaN
# 35                                                NaN            NaN
# 36                                                NaN        Exclude
# 37                                                NaN            NaN
# 38                                                NaN        Exclude
# 39                                                NaN        Exclude
#
#                                          llama_reason  llama_note
# 0   Not original research, Wrong primary aim, Not ...         NaN
# 1            Not original research, Wrong primary aim         NaN
# 2   Not original research, Wrong primary aim, Not ...         NaN
# 3            Not original research, Wrong primary aim         NaN
# 4            Not original research, Wrong primary aim         NaN
# 5            Not original research, Wrong primary aim         NaN
# 6   Not enough information, Wrong primary aim, Not...         NaN
# 7                                                 NaN         NaN
# 8                                                 NaN         NaN
# 9                                                 NaN         NaN
# 10                                                NaN         NaN
# 11  Wrong primary aim, Not data-driven fitting pro...         NaN
# 12  Not original research, Wrong primary aim, Not ...         NaN
# 13                                                NaN         NaN
# 14                                                NaN         NaN
# 15  Not original research, Wrong primary aim, Not ...         NaN
# 16  Not wearable devices, Wrong primary aim, Not d...         NaN
# 17  Not original research, Wrong primary aim, Not ...         NaN
# 18  Not original research, Wrong primary aim, Not ...         NaN
# 19  Not original research, Wrong primary aim, Not ...         NaN
# 20           Not original research, Wrong primary aim         NaN
# 21  Wrong primary aim, Not data-driven fitting pro...         NaN
# 22                                                NaN         NaN
# 23  Wrong primary aim, Not data-driven fitting pro...         NaN
# 24  Not original research, Wrong primary aim, Not ...         NaN
# 25  Not enough information, Not wearable devices, ...         NaN
# 26                                                NaN         NaN
# 27                                                NaN         NaN
# 28                                                NaN         NaN
# 29  Not wearable devices, Wrong primary aim, Not d...         NaN
# 30           Not original research, Wrong primary aim         NaN
# 31                                                NaN         NaN
# 32           Not original research, Wrong primary aim         NaN
# 33  Not original research, Wrong primary aim, Not ...         NaN
# 34                                                NaN         NaN
# 35                                                NaN         NaN
# 36           Not original research, Wrong primary aim         NaN
# 37                                                NaN         NaN
# 38  Not original research, Wrong primary aim, Not ...         NaN
# 39  Wrong primary aim, Not wearable devices, Not d...         NaN
